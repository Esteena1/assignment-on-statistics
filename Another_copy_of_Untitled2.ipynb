# %%
import pandas as pd
data=pd.read_csv(r'/content/Students_Performance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# **1.a..Number of males and females participated**

# %%
 print(data['gender'].value_counts())
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# **1.b..**

# %%
print("Parent level of Education")
print(data['parental level of education'].value_counts())
# Out:
# Parent level of Education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# **1.c..(i)**

# %%
from re import M
import seaborn as sns
import numpy as np
from scipy import stats

# Filter the dataset to compare based on gender:
Male = data[data['gender'] == 'male']
Female = data[data['gender'] == 'female']

# Extract math score for two groups
Male_score = Male[['math score','reading score','writing score']]

Female_score = Female[['math score','reading score','writing score']]

from statistics import mean
M_score_avge=Male_score[['math score','reading score','writing score']].mean()
print('Mean Score of Males in Math, reading and writing tests \n')
print(M_score_avge)

F_score_avge=Female_score[['math score','reading score','writing score']].mean()
print('Mean Score of Females in Math, reading and writing tests \n')
print(F_score_avge)

# Comparing Math score

if( M_score_avge['math score'] > F_score_avge['math score']):
        print('\n Average math_score of Boys = ', round(M_score_avge['math score'],2) ,\
              'is greater than of girls = ', round(F_score_avge['math score'],2))
else:
        print('Average math_score of Boys =' , round(M_score_avge['math score'],2) ,\
              'is less than of girls = ', round(F_score_avge['math score'],2) )

# Comparing Reading score

if( M_score_avge['reading score'] > F_score_avge['reading score']):
        print('\n Average  reading_score of Boys = ', round(M_score_avge['reading score'],2) ,\
              'is greater than of girls = ', round(F_score_avge['reading score'],2))
else:
        print('Average reading_score of Boys =' , round(M_score_avge['reading score'],2) ,\
              'is less than of girls = ', round(F_score_avge['reading score'],2) )

# Comparing Writing score

if( M_score_avge['writing score'] > F_score_avge['writing score']):
        print('\n Average writing_score of Boys = ', round(M_score_avge['writing score'],2) ,\
              'is greater than of girls = ', round(F_score_avge['writing score'],2))
else:
        print('Average writing_score of Boys =' , round(M_score_avge['writing score'],2) ,\
              'is less than of girls = ', round(F_score_avge['writing score'],2) )
# Out:
# Mean Score of Males in Math, reading and writing tests
#
# math score       68.821577
# reading score    65.545643
# writing score    63.446058
# dtype: float64
# Mean Score of Females in Math, reading and writing tests
#
# math score       63.376448
# reading score    72.590734
# writing score    72.467181
# dtype: float64
#
#  Average math_score of Boys =  68.82 is greater than of girls =  63.38
# Average reading_score of Boys = 65.55 is less than of girls =  72.59
# Average writing_score of Boys = 63.45 is less than of girls =  72.47

# %% [markdown]
# **1.c..(ii)**

# %%
# Filter dataset Test preparation Course
none = data[data['test preparation course'] == 'none']
Completed = data[data['test preparation course'] == 'completed']

# Extract math score for two groups
none_score = none[['math score','reading score','writing score']]

completed_score = Completed[['math score','reading score','writing score']]

from statistics import mean
N_score_avge=none_score[['math score','reading score','writing score']].mean()
print('Mean Score in different tests of those who not completed the test preparation course: \n')
print(N_score_avge)

C_score_avge=completed_score[['math score','reading score','writing score']].mean()
print('Mean Score in different tests of those who completed the test preparation course: \n')
print(C_score_avge)

# Comparing Math score

if( N_score_avge['math score'] > C_score_avge['math score']):
        print('\n Average of math_score of Boys = ', round(N_score_avge['math score'],2) ,\
              'is greater than of girls = ', round(C_score_avge['math score'],2))
else:
        print('Average of math_score of Boys =' , round(N_score_avge['math score'],2) ,\
              'is less than of girls = ', round(C_score_avge['math score'],2) )

# Comparing Reading score

if( N_score_avge['reading score'] > C_score_avge['reading score']):
        print('\n Average of reading_score of Boys = ', round(N_score_avge['reading score'],2) ,\
              'is greater than of girls = ', round(C_score_avge['reading score'],2))
else:
        print('Average of reading_score of Boys =' , round(N_score_avge['reading score'],2) ,\
              'is less than of girls = ', round(C_score_avge['reading score'],2) )

# Comparing Writing score

if( N_score_avge['writing score'] > C_score_avge['writing score']):
        print('\nAverage of writing_score of Boys = ', round(N_score_avge['writing score'],2) ,\
              'is greater than of girls = ', round(C_score_avge['writing score'],2))
else:
        print('Average of writing_score of Boys =' , round(N_score_avge['writing score'],2) ,\
              'is less than of girls = ', round(C_score_avge['writing score'],2) )
# Out:
# Mean Score in different tests of those who not completed the test preparation course:
#
# math score       63.789720
# reading score    66.417445
# writing score    64.457944
# dtype: float64
# Mean Score in different tests of those who completed the test preparation course:
#
# math score       69.966480
# reading score    74.175978
# writing score    74.684358
# dtype: float64
# Average of math_score of Boys = 63.79 is less than of girls =  69.97
# Average of reading_score of Boys = 66.42 is less than of girls =  74.18
# Average of writing_score of Boys = 64.46 is less than of girls =  74.68

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender", y="math score", x="test preparation course", data=data)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender", y="reading score", x="test preparation course", data=data)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender", y="writing score", x="test preparation course", data=data)
plt.show()

# %% [markdown]
# **1.d..(i)**

# %%
# Filter the dataset to compare based on gender:
Male = data[data['gender'] == 'male']
Female = data[data['gender'] == 'female']

# Extract math score for two groups
Male_score = Male[['math score','reading score','writing score']]

Female_score = Female[['math score','reading score','writing score']]

from statistics import stdev
M_score_var=Male_score[['math score','reading score','writing score']].std()
print('Score variation of Males in Math, reading and writing tests \n')
print(M_score_var)

F_score_var=Female_score[['math score','reading score','writing score']].std()
print('Score variation of Females in Math, reading and writing tests \n')
print(F_score_var)
# Out:
# Score variation of Males in Math, reading and writing tests
#
# math score       14.556411
# reading score    14.149594
# writing score    14.227225
# dtype: float64
# Score variation of Females in Math, reading and writing tests
#
# math score       16.029928
# reading score    14.411018
# writing score    14.844842
# dtype: float64

# %% [markdown]
# **1.d..(ii)**

# %%
# Filter dataset Test preparation Course
none = data[data['test preparation course'] == 'none']
Completed = data[data['test preparation course'] == 'completed']

# Extract math score for two groups
none_score = none[['math score','reading score','writing score']]

completed_score = Completed[['math score','reading score','writing score']]

from statistics import stdev
N_score_var=none_score[['math score','reading score','writing score']].std()
print('Score variation in different tests of those who not completed the test preparation course: \n')
print(N_score_var)

C_score_var=completed_score[['math score','reading score','writing score']].std()
print('Score variation in different tests of those who completed the test preparation course: \n')
print(C_score_var)
# Out:
# Score variation in different tests of those who not completed the test preparation course:
#
# math score       15.705689
# reading score    14.608896
# writing score    15.041667
# dtype: float64
# Score variation in different tests of those who completed the test preparation course:
#
# math score       14.521847
# reading score    13.537572
# writing score    13.236412
# dtype: float64

# %% [markdown]
# **1.e..**

# %%
from itertools import repeat,chain
e=data.nlargest(25, 'math score')
e.insert(6,'Bonus Point',5)
e
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
# 513  female        group E           bachelor's degree      standard
# 514  female        group E                 high school      standard
# 995    male        group E                some college      standard
# 512  female        group D                some college      standard
# 993    male        group C                some college      standard
# 994    male        group C          associate's degree      standard
# ...

# %% [markdown]
# **Case Study on Testing of hypothesis**

# %%
df=pd.read_csv(r'/content/Sales_add.csv')
df
# Out:
#        Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0    Month-1  Region - A  Manager - A                          132921
# 1    Month-2  Region - A  Manager - C                          149559
# 2    Month-3  Region - B  Manager - A                          146278
# 3    Month-4  Region - B  Manager - B                          152167
# 4    Month-5  Region - C  Manager - B                          159525
# 5    Month-6  Region - A  Manager - B                          137163
# 6    Month-7  Region - C  Manager - C                          130625
# 7    Month-8  Region - A  Manager - A                          131140
# 8    Month-9  Region - B  Manager - C                          171259
# 9   Month-10  Region - C  Manager - B                          141956
# 10  Month-11  Region - B  Manager - C                          159339
# 11  Month-12  Region - A  Manager - A                          178939
# ...

# %% [markdown]
# **2.a..**

# %% [markdown]
#  H_0 : mu_1 = mu_2 (There is no significant difference in sales before and after stepping into digital marketing)
#
# H_1: mu_1 < mu_2 (there is an increase in sales after stepping into digital marketing)

# %%
from scipy import stats

t_statistic,p=stats.ttest_rel(df['Sales_before_digital_add(in $)'], df['Sales_After_digital_add(in $)'])
print("t-statistic = ",round(t_statistic,2),"\n p_value = ",p)
alpha=0.05
if(p<alpha):
  print("Reject H_0, i.e., there is an increase in sales after stepping into digital marketing")
else:
  print("There is no significant difference in sales before and after stepping into digital marketing")
# Out:
# t-statistic =  -12.09
#  p_value =  6.336667004575778e-11
# Reject H_0, i.e., there is an increase in sales after stepping into digital marketing

# %% [markdown]
# **2.b..**

# %%
crosstab= pd.crosstab(df['Region'],df['Manager'])
print(crosstab)
print(stats.chi2_contingency(crosstab))
# Out:
# Manager     Manager - A  Manager - B  Manager - C
# Region
# Region - A            4            3            3
# Region - B            4            1            2
# Region - C            1            3            1
# Chi2ContingencyResult(statistic=3.050566893424036, pvalue=0.5493991051158094, dof=4, expected_freq=array([[4.09090909, 3.18181818, 2.72727273],
#        [2.86363636, 2.22727273, 1.90909091],
#        [2.04545455, 1.59090909, 1.36363636]]))

# %% [markdown]
# Here p_value is greater than 0.05, so we fail to  rejct the null hypothesis i.e., there is no relationship between the features 'Manager' and ' Region'
